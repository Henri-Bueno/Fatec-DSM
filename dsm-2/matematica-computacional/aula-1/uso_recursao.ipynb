# %%
# Exemplo de geração de números pares positivos utilizando
# uma definição recursiva
#
# Autor: Fabrício Galende Marques de Carvalho

from modelo_recursao import NumeroImparPositivo

impar_positivo = NumeroImparPositivo()

primeiro_impar = impar_positivo.n_esimo_impar(1)
segundo_impar = impar_positivo.n_esimo_impar(2)
decimo_impar = impar_positivo.n_esimo_impar(10)

print("Primeiro número ímpar positivo:", primeiro_impar)
print("Segundo número ímpar positivo:", segundo_impar)
print("Décimo número ímpar positivo:", decimo_impar)
# Out:
# Primeiro número ímpar positivo: 1
# Segundo número ímpar positivo: 3
# Décimo número ímpar positivo: 19
