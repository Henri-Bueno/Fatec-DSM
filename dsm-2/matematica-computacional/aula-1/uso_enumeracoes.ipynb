# %%
# Exemplo de utilização de enumerações
# 
# Autor: Fabrício Galende Marques de Carvalho

from modelo_enumeracoes import DDI
from IPython.display import display, HTML


print(DDI.BRASIL.name)
print(DDI.BRASIL.value)



# display(HTML( "No mês de " +  DDI.DEZEMBRO.name + " é comemorado o Natal. "))
# display(HTML( "Esse é o " + str(DDI.DEZEMBRO.value) + "<sup>o</sup>" + " mês do ano."))
# Out:
# BRASIL
# 55
